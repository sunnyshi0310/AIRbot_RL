# %%
from action_test import get_random_spiral_trajs

experiment_id = 0  # 决定随机种子
trajs = get_random_spiral_trajs(
    experiment_id, epochs=20, points_num=10, add_z=None, add_yaw=False, test_from=0
)

# %%
from robot_tools.painter import Painter2D
import numpy as np
points_num = 10
end_phase = 3 / 2 * np.pi
a, b, num_points, turns = 0.1, 0.1, points_num, 3
spiral_points = Painter2D.get_spiral_points(
    a, b, num_points, turns, end_phase=end_phase, points_allocate_mode="turn", plot=True
)
